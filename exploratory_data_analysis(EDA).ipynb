# %%
import pandas as pd
df=pd.read_excel("california_housing_test.csv.xlsx")
print(df)
df.head(15)
df.tail(30)
df.shape
df.describe()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# INTER QUARTILE RANGE (IQR)-percentages

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   int64
#  3   total_rooms         3000 non-null   int64
#  4   total_bedrooms      3000 non-null   int64
#  5   population          3000 non-null   int64
#  6   households          3000 non-null   int64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 211.1 KB

# %%
import matplotlib.pyplot as plt
df=pd.read_excel("california_housing_test.csv.xlsx")
plt.scatter(df.total_rooms,df.median_house_value,color="blue",marker='*')
plt.xlabel("total_rooms")
plt.ylabel("median_house_value")
plt.show()

# %%
import matplotlib.pyplot as plt
df=pd.read_excel('california_housing_test.csv.xlsx')
plt.scatter(df.median_income,df.median_house_value,color='violet',marker='+'),
plt.xlabel("median_income")
plt.ylabel("median_house_value")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=df[['median_income']]
y=df['median_house_value']
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[100]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4152864.69263998])

# %% [markdown]
# there are four types of machine learning- linear works in straight line ,requisition,supervised,

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
x=df[['median_income']]
y=df['median_house_value']
model=DecisionTreeRegressor()
model.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
model.predict([[100]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([483334.22222222])

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree

df = pd.read_excel("california_housing_test.csv.xlsx")

X = df[['median_income']]
y = df['median_house_value']

model = DecisionTreeRegressor(max_depth=3)
model.fit(X, y)

plt.figure(figsize=(10,6))
plot_tree(model, feature_names=['median_income'], filled=True)
plt.show()
